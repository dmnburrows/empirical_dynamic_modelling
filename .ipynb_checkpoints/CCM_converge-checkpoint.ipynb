# %%
#Import packages
#---------------------------------------
import sys
import os
import glob
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import matplotlib
import kedm
import warnings
import gc
warnings.filterwarnings("ignore", category=RuntimeWarning) 

#Import your modules
#---------------------------------------
import CCM as cfn
import proc_functions as pfn

sys.path.insert(0, os.path.expanduser('~/Documents/admin_tools'))
from admin_tools import admin_functions as adfn

# Define paths
#----------------------------------------------------------------------
code = '~/Documents/empirical_dynamic_modelling'
data = '/snl/scratch25/dburrows/CCM'

# %load_ext autoreload
sys.version
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# '3.7.4 (default, Aug 13 2019, 20:35:49) \n[GCC 7.3.0]'

# %% [markdown]
# # Estimate convergence after kEDM

# %%
#group data
#================
#group by sample
xmap_l = np.asarray([os.path.basename(i) for i in np.sort(glob.glob(data + '/*xmap*'))])

import re
bln = xmap_l[[bool(re.search(r'(BLN|PTZ05)', i)) for i in xmap_l]]
ptz20 = xmap_l[[bool(re.search(r'(PTZ20)', i)) for i in xmap_l]]

#unique sample list 
unq_l = np.append(np.unique(np.asarray([re.search(r'^(.*?_run-01)', i).group(1) for i in bln])),
          np.unique(np.asarray([''.join(re.search(r'^(.*?_run-01)(.{4})', i).groups()) for i in ptz20])))

# %%
# %autoreload
#estimate convergence
#======================

#parameters
n_int = 3 #expected interval files
int_l=[1.2, 1.4, 1.8] #expected intervals - make sure numbers are complete as in string! 
# -0.2 - i.e. allow a single negative value with <20% of the mean positive increase, to be convergent
ratio_val = -0.2 

curr = unq_l[0]
curr_l = glob.glob(f'{data}/{curr}*xmap*')

og, mask, conv_arr = pfn.conv_check(curr_l=curr_l, n_int=n_int, int_l = int_l, ratio_val=ratio_val)
# Out:
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:838: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap').any()
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:851: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   match = pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap')
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:896: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
conv_arr.shape
# Out:
# (4, 11039, 11039)

# %%
#size check
load = np.load(interval_l[0])
load1 = np.load(interval_l[1])
load2 = np.load(interval_l[2])
load3 = np.load(interval_l[3])


#check memory RAM usage of loading directly
print(f'{adfn.ram_gb(load)*4} GB')

# %%
#group load
#===============
#assert size match and interval check
assert(sum(pd.Series(curr_l).str.contains('interval')) == n_int), 'some interval files missing'
assert(sum(pd.Series(curr_l).str.contains('run-01_trace_CCMxmap')) == 1), 'missing complete xmap'
assert(sum(pd.Series(curr_l).str.contains('|'.join([f'-{str(i)}_' for i in int_l]))) == n_int), 'incorrect interval lengths'
assert(len(np.unique(curr_l)) == n_int + 1), 'some interval file lengths repeated'

#sort interval files in ascending length order
interval_l = np.sort(list(np.asarray(curr_l)[pd.Series(curr_l).str.contains('interval')]))
intervals = np.array([float(re.search(r'interval-([\d.]+)_trace', f).group(1)) for f in interval_l])
# Get sorted indices and reorder filenames accordingly
sorted_files = interval_l[np.argsort(intervals)]

#construct dictionary
conv_arr = []
conv_arr.append(np.ravel(np.load(np.asarray(curr_l)[pd.Series(curr_l).str.contains('run-01_trace_CCMxmap')][0])))
#array is constructed with full, and then decreasing time intervals
for x,s in enumerate(sorted_files):
    conv_arr.append(np.ravel(np.load(s)))
conv_arr=np.array(conv_arr)

#assert matrix size
assert all(t.shape == conv_arr[0].shape for t in conv_arr), "Not all tuples are the same"

# %%
# %autoreload
#visualise some examples
pfn.plot_random_convergence_profiles(conv_arr, n=50, seed=None)

# %%
#look for approx monotonicity
#==============================

#look for convergence ->NB if you increase number of intervals this needs changing!!!
#====================================================================
diffs = np.diff(conv_arr , axis=0)*-1 #+ive diffs mean increasing from small->larger interval
sums = (diffs > 0).sum(axis=0) #how many +ive steps are there
monotonic_bool = sums > 2 #identify complete monotonic 

partial_bool = sums == 2 #identify 2/3 monotonic
partialzero_bool = (partial_bool) & ((diffs == 0).sum(axis=0) > 0) #2/3 monotonic and 1 at 0

#check to see what ratio of -ive to mean+ive is good
partial_only = diffs[:,(partial_bool) & (~partialzero_bool)] #diffs with partially monotonic and 1 negative value
po_ind = np.argwhere((partial_bool) & (~partialzero_bool))[:,0] # indeces of partial_only cells

arr = partial_only.copy()
arr[arr < 0] = np.nan                # mask negatives directly in the array (in-place)
mean_pos = np.nanmean(arr, axis=0)  # mean across rows, ignoring NaNs

row_indices = (partial_only < 0).argmax(axis=0)
po_neg_values = partial_only[row_indices, np.arange(partial_only.shape[1])] #returns values of all negative in po

ratio=po_neg_values/mean_pos #ratio is ratio of negative / mean pos

pm_ind = po_ind[ratio>ratio_val] #indeces in diffs of cells that pass the 20% threshold and are partially monotonic

partialpass_bool = np.zeros(diffs.shape[1], dtype=bool)
partialpass_bool[pm_ind] = True #2/3 monotonic and 1 <20% of mean pos


#get final bool of all passing cells
conv_bool = partialpass_bool | monotonic_bool | partialzero_bool
og = np.load(np.asarray(curr_l)[pd.Series(curr_l).str.contains('run-01_trace_CCMxmap')][0])
mask = conv_bool.reshape(og.shape)
conv_arr = conv_arr.reshape(tuple(np.append(4,og.shape)))

# #remove large unneeded variables
del conv_bool, partialpass_bool, pm_ind, ratio, po_neg_values, mean_pos, arr, po_ind, partial_only, partialzero_bool, partial_bool, monotonic_bool, sums, diffs
gc.collect()
# Out:
# 8

# %%
#visualise degree of slight negativity that exists in partially monotonic
plt.hist(po_neg_values, bins=100)
plt.show()

# %%
#parameters
n_int = 3 #expected interval files
int_l=[1.2, 1.4, 1.8] #expected intervals - make sure numbers are complete as in string! 
# -0.2 - i.e. allow a single negative value with <20% of the mean positive increase, to be convergent
ratio_val = -0.2 

curr = unq_l[0]
curr_l = glob.glob(f'{data}/{curr}*xmap*')
curr_l

# %%
#visualise ratio of negative / mean_pos
plt.hist(ratio, bins=100, range=(-10,0))
plt.show()

# %% [markdown]
# # Convergence statistics

# %%
# %autoreload
#Compute fraction of cells that converge, and mean CCM in convergent cells
#==========================================================
from tqdm import tqdm

#parameters
n_int = 3 #expected interval files
int_l=[1.2, 1.4, 1.8] #expected intervals - make sure numbers are complete as in string! 
# -0.2 - i.e. allow a single negative value with <20% of the mean positive increase, to be convergent
ratio_val = -0.2 

results = []
# Loop through each unique base name
for curr in tqdm(unq_l, desc='Processing CCM files'):
    curr_l = glob.glob(f'{data}/{curr}*xmap*')

    og, mask, conv_arr = pfn.conv_check(curr_l=curr_l, n_int=n_int, int_l=int_l, ratio_val=ratio_val)
    conv_frac = np.ravel(mask).sum() / mask.size
    mean = np.mean(og[mask])
    med = np.median(og[mask])
    std = np.std(og[mask])

    results.append({
        "name": curr,
        "converged_fraction": conv_frac,
        "mean_CCM": mean,
        "median_CCM": med,
        "std_CCM": std
    })

results_df = pd.DataFrame(results)
results_df.to_csv(f'{data}/ccm_convergence_summary.csv', index=False)
# Out:
# Processing CCM files:   0%|                 | 0/29 [00:00<?, ?it/s]/nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:838: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap').any()
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:851: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   match = pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap')
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:896: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#
# Processing CCM files: 100%|████████| 29/29 [05:46<00:00, 11.93s/it]

# %%
#Compare across smoothed vs non-smoothed data
df = pd.read_csv(f'{data}/ccm_convergence_summary.csv')
df['cond'] = [i.split('_')[3] for i in df['name'].values]
df.loc[df['cond'] == 'PTZ20', 'cond'] = [i[-3:] for i in df[df['cond']=='PTZ20']['name'].values]
df = df.drop(24)
df
# Out:
#                                                  name  converged_fraction  \
# 0     PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01            0.220486
# 1   PTZ-WILDTYPE-03_2photon_sess-01-6dpf_PTZ05_run-01            0.236477
# 2     PTZ-WILDTYPE-06_2photon_sess-01-6dpf_BLN_run-01            0.114505
# 3   PTZ-WILDTYPE-06_2photon_sess-01-6dpf_PTZ05_run-01            0.223393
# 4     PTZ-WILDTYPE-07_2photon_sess-01-6dpf_BLN_run-01            0.097883
# 5   PTZ-WILDTYPE-07_2photon_sess-01-6dpf_PTZ05_run-01            0.171925
# 6     PTZ-WILDTYPE-10_2photon_sess-01-6dpf_BLN_run-01            0.199051
# 7   PTZ-WILDTYPE-10_2photon_sess-01-6dpf_PTZ05_run-01            0.192373
# 8     PTZ-WILDTYPE-11_2photon_sess-01-6dpf_BLN_run-01            0.139905
# 9   PTZ-WILDTYPE-11_2photon_sess-01-6dpf_PTZ05_run-01            0.200085
# 10    PTZ-WILDTYPE-13_2photon_sess-01-6dpf_BLN_run-01            0.145162
# 11  PTZ-WILDTYPE-13_2photon_sess-01-6dpf_PTZ05_run-01            0.190476
# 12    PTZ-WILDTYPE-14_2photon_sess-01-6dpf_BLN_run-01            0.123024
# 13  PTZ-WILDTYPE-14_2photon_sess-01-6dpf_PTZ05_run-01            0.205473
# 14    PTZ-WILDTYPE-15_2photon_sess-01-6dpf_BLN_run-01            0.136139
# 15  PTZ-WILDTYPE-15_2photon_sess-01-6dpf_PTZ05_run-01            0.243686
# 16  PTZ-WILDTYPE-03_2photon_sess-01-6dpf_PTZ20_run...            0.031411
# 17  PTZ-WILDTYPE-04_2photon_sess-01-6dpf_PTZ20_run...            0.167561
# 18  PTZ-WILDTYPE-07_2photon_sess-01-6dpf_PTZ20_run...            0.307582
# 19  PTZ-WILDTYPE-08_2photon_sess-01-6dpf_PTZ20_run...            0.175161
# 20  PTZ-WILDTYPE-08_2photon_sess-01-6dpf_PTZ20_run...            0.168011
# 21  PTZ-WILDTYPE-09_2photon_sess-01-6dpf_PTZ20_run...            0.164459
# 22  PTZ-WILDTYPE-10_2photon_sess-01-6dpf_PTZ20_run...            0.456358
# 23  PTZ-WILDTYPE-10_2photon_sess-01-6dpf_PTZ20_run...            0.430046
# 25  PTZ-WILDTYPE-12_2photon_sess-01-6dpf_PTZ20_run...            0.183908
# 26  PTZ-WILDTYPE-13_2photon_sess-01-6dpf_PTZ20_run...            0.120330
# 27  PTZ-WILDTYPE-14_2photon_sess-01-6dpf_PTZ20_run...            0.204485
# 28  PTZ-WILDTYPE-14_2photon_sess-01-6dpf_PTZ20_run...            0.427444
#
#     mean_CCM  median_CCM   std_CCM   cond
# 0   0.144942    0.099332  0.138914    BLN
# 1   0.195922    0.161757  0.151364  PTZ05
# 2   0.054851    0.023549  0.090167    BLN
# 3   0.152824    0.116899  0.133857  PTZ05
# 4   0.017930    0.012163  0.032928    BLN
# 5   0.117315    0.081343  0.112304  PTZ05
# 6   0.101602    0.056948  0.117132    BLN
# 7   0.103642    0.076450  0.094364  PTZ05
# 8   0.037430    0.018518  0.060483    BLN
# 9   0.103631    0.076895  0.093859  PTZ05
# 10  0.049862    0.022349  0.074023    BLN
# 11  0.114876    0.070209  0.125966  PTZ05
# 12  0.036023    0.019820  0.054195    BLN
# 13  0.120395    0.086403  0.111751  PTZ05
# 14  0.088534    0.055288  0.095665    BLN
# 15  0.204536    0.170047  0.150914  PTZ05
# 16  0.307729    0.291577  0.192214    sz_
# 17  0.489117    0.504761  0.188688    sz_
# 18  0.509693    0.529845  0.183132    sz_
# 19  0.096048    0.061123  0.103021    pre
# 20  0.360194    0.348528  0.193768    sz_
# 21  0.092818    0.045190  0.120548    pre
# 22  0.388436    0.379623  0.233397    pre
# 23  0.665124    0.705699  0.175990    sz_
# 25  0.641933    0.683211  0.201426    sz_
# 26  0.089419    0.042326  0.114252    pre
# 27  0.166258    0.111306  0.164168    pre
# 28  0.691913    0.743181  0.192361    sz_

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set seaborn style
sns.set(style="white", context="talk", font_scale=1.2)

# Define custom colors and desired order
custom_palette = {
    'BLN': 'black',
    'PTZ05': 'teal',
    'pre': 'orangered',     # light red
    'sz_': 'firebrick'      # dark red
}

order = ['BLN', 'PTZ05', 'pre', 'sz_']  # desired plotting order

# Create the stripplot
g = sns.stripplot(
    data=df,
    x='cond',
    y='converged_fraction',
    palette=custom_palette,
    order=order,
    jitter=True,
    alpha=1,
    size=7
)

# Axis labels (optional)
g.set_xlabel("Condition")
g.set_ylabel("Converged Fraction")

# Clean up figure
sns.despine()
plt.tight_layout()
plt.savefig('prac.svg', transparent=True)
plt.show()
# Out:
# /home/dburrows/.local/lib/python3.7/site-packages/ipykernel_launcher.py:26: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
import pandas as pd
from scipy.stats import sem

# Group by condition and compute mean and SEM
summary = df.groupby('cond')['converged_fraction'].agg(['mean', sem]).reset_index()

# Rename columns for clarity
summary.columns = ['Condition', 'Mean', 'SEM']

# Print results
print(summary)
# Out:
#   Condition      Mean       SEM
# 0       BLN  0.147019  0.014835
# 1     PTZ05  0.207986  0.008705
# 2       pre  0.224158  0.059603
# 3       sz_  0.245138  0.056214

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set seaborn style
sns.set(style="white", context="talk", font_scale=1.2)

# Define custom colors and desired order
custom_palette = {
    'BLN': 'black',
    'PTZ05': 'teal',
    'pre': 'orangered',     # light red
    'sz_': 'firebrick'      # dark red
}

order = ['BLN', 'PTZ05', 'pre', 'sz_']  # desired plotting order

# Create the stripplot
g = sns.stripplot(
    data=df,
    x='cond',
    y='mean_CCM',
    palette=custom_palette,
    order=order,
    jitter=True,
    alpha=1,
    size=7
)

# Axis labels (optional)
g.set_xlabel("Condition")
g.set_ylabel("Converged Fraction")

# Clean up figure
sns.despine()
plt.tight_layout()
plt.savefig('prac.svg', transparent=True)
plt.show()
# Out:
# /home/dburrows/.local/lib/python3.7/site-packages/ipykernel_launcher.py:26: FutureWarning: Passing `palette` without assigning `hue` is deprecated.

# %%
import pandas as pd
from scipy.stats import sem

# Group by condition and compute mean and SEM
summary = df.groupby('cond')['mean_CCM'].agg(['mean', sem]).reset_index()

# Rename columns for clarity
summary.columns = ['Condition', 'Mean', 'SEM']

# Print results
print(summary)
# Out:
#   Condition      Mean       SEM
# 0       BLN  0.066397  0.014890
# 1     PTZ05  0.139143  0.014408
# 2       pre  0.166596  0.057267
# 3       sz_  0.523672  0.057122

# %%
#Visualise convergence patterns
#==========================================
#parameters
n_int = 3 #expected interval files
int_l=[1.2, 1.4, 1.8] #expected intervals - make sure numbers are complete as in string! 
# -0.2 - i.e. allow a single negative value with <20% of the mean positive increase, to be convergent
ratio_val = -0.2

curr = unq_l[0]
curr_l = glob.glob(f'{data}/{curr}*xmap*')

og, mask, conv_arr = pfn.conv_check(curr_l=curr_l, n_int=n_int, int_l=int_l, ratio_val=ratio_val)

curr=np.asarray([np.ravel(i) for i in conv_arr])
curr=curr[:,np.ravel(mask)]

# %%
#sanity check
assert (np.diff(curr,axis=0) > 0).sum() == 0, 'some non monotonic' #should be 0 if fully monotonic
#ratio = 0 fully monotonic
#visualise some examples
pfn.plot_random_convergence_profiles(curr, n=50, seed=None)

# %%
#sanity check for non-monotonic
sli=(np.diff(curr,axis=0) > 0)
cols_with_true = np.any(sli, axis=0)
cols_indices = np.where(cols_with_true)[0]
go=curr[:,cols_indices] #remaining convergences with 1 negative slope
difs = np.diff(go,axis=0)*-1
arr = difs.copy()
arr[arr < 0] = np.nan                # mask negatives directly in the array (in-place)
mean_pos = np.nanmean(arr, axis=0)  # mean across rows, ignoring NaNs
row_indices = (difs < 0).argmax(axis=0)
po_neg_values = difs[row_indices, np.arange(difs.shape[1])] #returns values of all negative in po
ratio=po_neg_values/mean_pos #ratio is ratio of negative / mean pos
assert min(ratio) > ratio_val, 'ratio val calculation failed'

plt.hist(ratio)
plt.show()

# %%
#ratio = -0.2 
#visualise some examples
pfn.plot_random_convergence_profiles(curr, n=50, seed=None)

# %%
#Visualise convergence patterns through kmeans
#==========================================
#parameters
n_int = 3 #expected interval files
int_l=[1.2, 1.4, 1.8] #expected intervals - make sure numbers are complete as in string! 
# -0.2 - i.e. allow a single negative value with <20% of the mean positive increase, to be convergent
ratio_val = -0.2

results = []
# Loop through each unique base name
for curr in tqdm(unq_l, desc='Processing CCM files'):
    curr_l = glob.glob(f'{data}/{curr}*xmap*')

    og, mask, conv_arr = pfn.conv_check(curr_l=curr_l, n_int=n_int, int_l=int_l, ratio_val=ratio_val)
    
    curr=np.asarray([np.ravel(i) for i in conv_arr])
    curr=curr[:,np.ravel(mask)]
    subset = curr[:,np.random.choice(curr.shape[1], size=10000, replace=False)][:,:]
    
    results.append(subset)

# Stack all scaled data from all samples
res=np.hstack((results))

# # Run KMeans
k = 10  # or any k ≤ number of samples
kmeans = KMeans(n_clusters=k, random_state=0)
labels = kmeans.fit_predict(res.T)
# Out:
# Processing CCM files:   0%|                 | 0/29 [00:00<?, ?it/s]/nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:838: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap').any()
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:851: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   match = pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap')
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:896: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   match = pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap')
# Processing CCM files: 100%|████████| 29/29 [06:04<00:00, 12.56s/it]

# %%
fin = []
lab_l = np.unique(labels)
for s in lab_l:
    curr = res[:,labels == s]
    time = np.tile(np.arange(0,4),curr.shape[1])
    lab = np.repeat(np.arange(curr.shape[1]),4)
    curr=np.ravel(curr.T)
    clus = np.repeat(s, curr.shape)

    df = pd.DataFrame({
        'Time': time,
        'Sample': lab,
        'Cluster': clus,
        'Data': curr
    })
    fin.append(df)

# Combine all into one DataFrame
final_df = pd.concat(fin, ignore_index=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Mapping numeric timepoints to meaningful labels
label_map = {0: 'Full', 1: '1/2', 2: '1/4', 3: '1/8'}
order = [3, 2, 1, 0]

# Prepare DataFrame
plot_df = final_df.copy()
plot_df['TimeLabel'] = plot_df['Time'].map(label_map)
plot_df['TimeOrder'] = plot_df['Time'].map(lambda x: order.index(x))

# Plot with thicker lines
g = sns.relplot(
    data=plot_df.sort_values("TimeOrder"),
    x="TimeLabel",
    y="Data",
    col="Cluster",
    col_wrap=4,
    kind="line",
    height=3,
    aspect=1.2,
    linewidth=3.0 ,
    color = 'grey'
)

# Remove axis labels but keep ticks
for ax in g.axes.flat:
    ax.set_xlabel("")  # Remove x-axis label
    ax.set_ylabel("")  # Remove y-axis label
    ax.tick_params(axis='y', labelsize=15)  # Increase y-tick label size
    ax.tick_params(axis='x', labelsize=15)
    ax.set_xticks(['1/8', '1/4', '1/2', 'Full'])

# Keep cluster titles
g.set_titles("Cluster {col_name}")

plt.tight_layout()
plt.savefig('prac.svg', transparent=True)
plt.show()

# %%
#fraction per cluster
# Drop duplicates to count each sample only once per cluster
sample_cluster_df = final_df[['Sample', 'Cluster']].drop_duplicates()

# Count samples per cluster
cluster_counts = sample_cluster_df['Cluster'].value_counts().sort_index()

# Total number of unique samples
total_samples = cluster_counts.sum()

# Compute fractions
cluster_fractions = cluster_counts / total_samples

# Print nicely
for cluster, frac in cluster_fractions.items():
    print(f"Cluster {cluster}: {frac:.2%} of samples")
# Out:
# Cluster 0: 42.15% of samples
# Cluster 1: 2.58% of samples
# Cluster 2: 3.31% of samples
# Cluster 3: 11.92% of samples
# Cluster 4: 2.93% of samples
# Cluster 5: 20.86% of samples
# Cluster 6: 4.72% of samples
# Cluster 7: 2.02% of samples
# Cluster 8: 3.12% of samples
# Cluster 9: 6.38% of samples

# %%
#Visualise convergence patterns through PCA
#==========================================
#parameters
n_int = 3 #expected interval files
int_l=[1.2, 1.4, 1.8] #expected intervals - make sure numbers are complete as in string! 
# -0.2 - i.e. allow a single negative value with <20% of the mean positive increase, to be convergent
ratio_val = -0.0 

results = []
# Loop through each unique base name
for curr in tqdm(unq_l[:1], desc='Processing CCM files'):
    curr_l = glob.glob(f'{data}/{curr}*xmap*')

    og, mask, conv_arr = pfn.conv_check(curr_l=curr_l, n_int=n_int, int_l=int_l, ratio_val=ratio_val)
    from sklearn.preprocessing import StandardScaler
    
    curr=np.asarray([np.ravel(i) for i in conv_arr])
    curr=curr[:,np.ravel(mask)]
    subset = curr[:,np.random.choice(curr.shape[1], size=10000, replace=False)][:,:]

    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(subset)  
    from sklearn.decomposition import PCA
    pca = PCA(n_components=4)
    embedding = pca.fit_transform(scaled_data)
    results.append(embedding)
res=np.vstack(results)
# Out:
# Processing CCM files:   0%|                  | 0/1 [00:00<?, ?it/s]/nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:838: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap').any()
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:851: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   match = pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap')
# /nadata/mnlsc/home/dburrows/Documents/empirical_dynamic_modelling/proc_functions.py:896: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   match = pd.Series(curr_l).str.contains(r'run-01_(trace|sz_trace|pre_trace)_CCMxmap')
# Processing CCM files: 100%|██████████| 1/1 [00:14<00:00, 14.44s/it]

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Set number of clusters
n_clusters = 10  # you can change this

# Fit KMeans
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(res)

# Optional: view cluster centers
centroids = kmeans.cluster_centers_

# # Plot if res is 2D
plt.scatter(res[:, 0], res[:, 1], c=labels, cmap='tab10', s=5, alpha=0.6)
plt.scatter(centroids[:, 0], centroids[:, 1], c='black', s=50, marker='x')
plt.title(f"KMeans Clustering (k={n_clusters})")
plt.xlabel("Dim 1")
plt.ylabel("Dim 2")
plt.tight_layout()
plt.show()

# %%
fin = []
lab_l = np.unique(labels)
for s in lab_l:
    curr = res[labels == s]
    time = np.tile(np.arange(0,4),len(curr))
    lab = np.repeat(np.arange(len(curr)),4)
    curr=np.ravel(curr.T)
    clus = np.repeat(s, curr.shape)

    df = pd.DataFrame({
        'Time': time,
        'Sample': lab,
        'Cluster': clus,
        'Data': curr
    })
    fin.append(df)

# Combine all into one DataFrame
final_df = pd.concat(fin, ignore_index=True)

# %%
import seaborn as sns
sns.relplot(data=final_df, x = 'Time', y='Data', col = 'Cluster', col_wrap=4, kind='line')
plt.show()

# %%
#group data
#================
#group by sample
xmap_l = np.asarray([os.path.basename(i) for i in np.sort(glob.glob(data + '/smoothed/sigma_4/*xmap*'))])

import re
bln = xmap_l[[bool(re.search(r'(BLN|PTZ05)', i)) for i in xmap_l]]
ptz20 = xmap_l[[bool(re.search(r'(PTZ20)', i)) for i in xmap_l]]

#unique sample list 
unq_l = np.append(np.unique(np.asarray([re.search(r'^(.*?_run-01)', i).group(1) for i in bln])),
          np.unique(np.asarray([''.join(re.search(r'^(.*?_run-01)(.{4})', i).groups()) for i in ptz20])))

# %%
#Run on smoothed data
#==========================================================
from tqdm import tqdm

#parameters
n_int = 3 #expected interval files
int_l=[1.2, 1.4, 1.8] #expected intervals - make sure numbers are complete as in string! 
# -0.2 - i.e. allow a single negative value with <20% of the mean positive increase, to be convergent
ratio_val = -0.2 

results = []
# Loop through each unique base name
for curr in tqdm(unq_l, desc='Processing CCM files'):
    curr_l = glob.glob(f'{data}/smoothed/sigma_4/{curr}*xmap*')

    og, mask, conv_arr = conv_check_h5(curr_l=curr_l, n_int=n_int, int_l=int_l, ratio_val=ratio_val)
    conv_frac = np.ravel(mask).sum() / mask.size
    mean = np.mean(og[mask])
    med = np.median(og[mask])
    std = np.std(og[mask])

    results.append({
        "name": curr,
        "converged_fraction": conv_frac,
        "mean_CCM": mean,
        "median_CCM": med,
        "std_CCM": std
    })

results_df = pd.DataFrame(results)
results_df.to_csv(f'{data}/ccm_convergence_summary_sigma-4.csv', index=False)
# Out:
# Processing CCM files:   0%|                 | 0/29 [00:00<?, ?it/s]/home/dburrows/.local/lib/python3.7/site-packages/ipykernel_launcher.py:45: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# /home/dburrows/.local/lib/python3.7/site-packages/ipykernel_launcher.py:58: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# /home/dburrows/.local/lib/python3.7/site-packages/ipykernel_launcher.py:109: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# Processing CCM files: 100%|████████| 29/29 [07:16<00:00, 15.07s/it]

# %%
#Compare across smoothed vs non-smoothed data
sigma0 = pd.read_csv(f'{data}/ccm_convergence_summary.csv')
sigma2 = pd.read_csv(f'{data}/ccm_convergence_summary_sigma-2.csv')
sigma4 = pd.read_csv(f'{data}/ccm_convergence_summary_sigma-4.csv')
sigma0['mode'] = 0
sigma2['mode'] = 2
sigma4['mode'] = 4
cat=pd.concat([sigma0, sigma2, sigma4])
cat['cond'] = [i.split('_')[3] for i in cat['name'].values]

# %%
cat
# Out:
#                                                  name  converged_fraction  \
# 0     PTZ-WILDTYPE-03_2photon_sess-01-6dpf_BLN_run-01            0.220486
# 1   PTZ-WILDTYPE-03_2photon_sess-01-6dpf_PTZ05_run-01            0.236477
# 2     PTZ-WILDTYPE-06_2photon_sess-01-6dpf_BLN_run-01            0.114505
# 3   PTZ-WILDTYPE-06_2photon_sess-01-6dpf_PTZ05_run-01            0.223393
# 4     PTZ-WILDTYPE-07_2photon_sess-01-6dpf_BLN_run-01            0.097883
# ..                                                ...                 ...
# 24  PTZ-WILDTYPE-12_2photon_sess-01-6dpf_PTZ20_run...            0.049238
# 25  PTZ-WILDTYPE-12_2photon_sess-01-6dpf_PTZ20_run...            0.067785
# 26  PTZ-WILDTYPE-13_2photon_sess-01-6dpf_PTZ20_run...            0.033044
# 27  PTZ-WILDTYPE-14_2photon_sess-01-6dpf_PTZ20_run...            0.058794
# 28  PTZ-WILDTYPE-14_2photon_sess-01-6dpf_PTZ20_run...            0.292786
#
#     mean_CCM  median_CCM   std_CCM  mode   cond
# 0   0.144942    0.099332  0.138914     0    BLN
# 1   0.195922    0.161757  0.151364     0  PTZ05
# 2   0.054851    0.023549  0.090167     0    BLN
# 3   0.152824    0.116899  0.133857     0  PTZ05
# 4   0.017930    0.012163  0.032928     0    BLN
# ..       ...         ...       ...   ...    ...
# 24  0.272503    0.237626  0.183931     4  PTZ20
# 25  0.717224    0.747246  0.169081     4  PTZ20
# 26  0.247877    0.208149  0.185765     4  PTZ20
# 27  0.330825    0.296729  0.209901     4  PTZ20
# 28  0.796353    0.837259  0.147312     4  PTZ20
#
# [87 rows x 7 columns]

# %%
import seaborn as sns
sns.catplot(data=cat, y='converged_fraction', x='mode', col='cond')
plt.show()

# %%
import seaborn as sns
sns.catplot(data=cat, y='mean_CCM', x='mode', col='cond')
plt.show()

# %%
import seaborn as sns
sns.catplot(data=cat, y='median_CCM', x='mode', col='cond')
plt.show()
